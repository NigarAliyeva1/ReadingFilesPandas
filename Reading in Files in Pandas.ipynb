# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\nigar\Downloads\Companies.csv")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df2= pd.read_csv(r"C:\Users\nigar\Downloads\Companies - Copy.txt",sep='\t')
df2
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df2= pd.read_table(r"C:\Users\nigar\Downloads\Companies - Copy.txt")
df2
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df3= pd.read_json(r"C:\Users\nigar\Downloads\json_sample.json")
df3
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df4 = pd.read_excel(r"C:\Users\nigar\Downloads\Apocolypse Food Prep - Drill Down Tutorial.xlsx")
df4
# Out:
#       Store       Product  Price       Date
# 0   Walmart          Rice  25.00 2022-01-01
# 1    Costco          Rice  23.00 2022-01-01
# 2    Target          Rice  22.99 2022-01-01
# 3   Walmart          Rice  25.75 2022-02-01
# 4    Costco          Rice  23.99 2022-02-01
# ..      ...           ...    ...        ...
# 79   Costco  Water Filter  29.00 2022-01-01
# 80   Target  Water Filter  38.00 2022-01-01
# 81  Walmart  Water Filter  39.00 2022-03-01
# 82   Costco  Water Filter  31.00 2022-03-01
# 83   Target  Water Filter  39.00 2022-03-01
#
# [84 rows x 4 columns]

# %%
pd.set_option('display.max.rows',85)

# %%
df4 = pd.read_excel(r"C:\Users\nigar\Downloads\Apocolypse Food Prep - Drill Down Tutorial.xlsx")
df4
# Out:
#       Store            Product  Price       Date
# 0   Walmart               Rice  25.00 2022-01-01
# 1    Costco               Rice  23.00 2022-01-01
# 2    Target               Rice  22.99 2022-01-01
# 3   Walmart               Rice  25.75 2022-02-01
# 4    Costco               Rice  23.99 2022-02-01
# 5    Target               Rice  23.25 2022-02-01
# 6   Walmart               Rice  26.99 2022-03-01
# 7    Costco               Rice  24.99 2022-03-01
# 8    Target               Rice  24.25 2022-03-01
# 9   Walmart               Rice  26.99 2022-04-01
# 10   Costco               Rice  25.25 2022-04-01
# 11   Target               Rice  24.75 2022-04-01
# 12  Walmart        Dried Beans  22.99 2022-01-01
# 13   Costco        Dried Beans  20.99 2022-01-01
# 14   Target        Dried Beans  23.99 2022-01-01
# 15  Walmart        Dried Beans  23.99 2022-02-01
# 16   Costco        Dried Beans  22.99 2022-02-01
# 17   Target        Dried Beans  24.99 2022-02-01
# ...

# %%
pd.set_option('display.max.columns',40)

# %%
df3= pd.read_json(r"C:\Users\nigar\Downloads\json_sample.json")
df3
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  227 non-null    object
#  1   Region   227 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df2.shape
# Out:
# (227, 2)

# %%
df.head(10)
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
# 9    10   Chevron Corporation              Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# ...

# %%
df2.tail(10)
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
df['Rank']
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#      ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
# Name: Rank, Length: 100, dtype: int64

# %%
df2.loc[210]
# Out:
# Country                                Uganda
# Region     SUB-SAHARAN AFRICA
# Name: 210, dtype: object

# %%
df2.iloc[210]
# Out:
# Country                                Uganda
# Region     SUB-SAHARAN AFRICA
# Name: 210, dtype: object
